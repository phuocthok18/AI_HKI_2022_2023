# %% [markdown]
# <a href="https://colab.research.google.com/github/phuocthok18/AI_HKI_2022_2023/blob/main/Tuan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from openpyxl import Workbook


wb = Workbook()
sheet = wb.active
sheet['A1'] = 'nguyen van A'
sheet['B1'] = 'ngjueyn van B'
sheet['A2'] = 'huynh vana trong'
sheet['B2'] = 'le vna A'
wb.save('test.xlsx')

# %%
temp1 = sheet['A1']
temp2 = sheet['A2']
temp3 = sheet.cell(row = 3, column = 1)
temp4 = sheet.cell(row = 4, column = 1)

print(temp1.value, temp2.value, temp3.value, temp4.value)
# Out:
# nguyen van A huynh vana trong None None

# %%
my_wb = Workbook()
my_sheet = my_wb.active
c1 = my_sheet.cell(row = 1, column =1)
c1.value = 'Dang tri dung'
c2 = my_sheet.cell(row = 2, column =2)
c1.value = 'tran cuong'
c3 = my_sheet['A2']
c3.value = 'trang'
c4 = my_sheet['B2']
c4.value = 'ngoc lan'
my_wb.save('Book2.xlsx')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(6)
y = x + 1
plt.plot(x, y, 'o--')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
N =16
x = np.linspace(0,15,16)
y = np.logspace(0.1, 2, 16)
plt.plot(x,y,'--o')
plt.show()

# %%
x = [4,5,3,1,6,7]
plt.plot(x)
plt.show()

# %%
x = np.arange(6)
y = x + 1
plt.plot(x, y, 'o--')
plt.plot(x, -y, 'o-')
plt.title('y=x va y=-x')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
n = 16
x=np.linspace(0,15,16)
y=x
plt.plot(x,y,'o--')
plt.axis('off')
# Out:
# (-0.75, 15.75, -0.75, 15.75)

# %%
N =16
x = np.linspace(0,15,16)
y = np.logspace(0.1, 2, 16)
plt.plot(x,y,'--o')

# %%
x = [4,5,3,1,6,7]
plt.plot(x)

# %%
x = np.arange(25)
plt.plot(x, x**3 +1)        #x mũ 3

# %%
x = np. arange(7)
plt.plot(x, -x**2)
plt.plot(x, -x**3)
plt.plot(x, -2*x)
plt.plot(x, -2**x)

# %%
x = np.arange(7)
plt.plot(x, -x**2,':', x, -x**3,'--', x, -2*x,'-', x, -2**x,'-.')
plt.grid(True)
plt.savefig('text.png')

# %%
x= np.arange(15)
plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.subplot(2,2,1)
plt.plot(x, -x**2, color='g')

plt.subplot(2,2,2)
plt.plot(x,-x**3, color='r')

plt.subplot(2,2,3)
plt.plot(x,-2*x, color='b')

plt.subplot(2,2,4)
plt.plot(x, -2**x, color='y')

# %%
plt.axis([0,100,0,10])
plt.scatter(60,5, s=1000, color='b', alpha=1)               #alpha: độ đậm nhạt
plt.scatter(80,3, s=1000, color='b', alpha=.3)
plt.scatter(100,1, s=1000, color='b', alpha=.1)

# %%
plt.plot([3,5],[6,10],linewidth = 5, color = 'b')
plt.text(4,7,'Text')
# Out:
# Text(4, 7, 'Text')

# %%
plt.arrow(30,30,30,60, head_length=4, head_width = 3, color='b' )

# %%
x = np.arange(4)
y= np.random.rand(4)
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.arange(4)
y= np.random.rand(3,4)
plt.bar(x+0,y[0], color='b', width=0.25)
plt.bar(x + 0.25, y[1], color='y',width=0.25)
plt.bar(x+0.5,y[2],color='g', width=0.25)
# Out:
# <BarContainer object of 4 artists>

# %%
N=1000
x= np.random.rand(N)
y= np.random.rand(N)
color =np.random.rand(N)
size = 20
plt.scatter(x,y,s= size,c=color,alpha=1)
plt.show()
